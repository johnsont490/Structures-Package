# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
materials = []
densities = []
elasticmodulus = []
yieldstrength = []

# %%
materiallist = ["firstset.txt","secondset.txt","thirdset.txt","fourthset.txt","fifthset.txt","sixthset.txt","seventhset.txt","eighthset.txt","ninthset.txt","misc.txt"]

for index in materiallist:
    with open(index) as f:
            list_lines = f.readlines()
            for line in list_lines:
                line = line.strip("\n")
                web_id = requests.get(f"https://www.azom.com/article.aspx?ArticleID={line}").text
                soup = bs(web_id, "html.parser")
                material = soup.find("h1")
                materials.append(material.text.strip())
                
                #first set
                if index == "firstset.txt":
                    table = soup.find_all("table",attrs={"style":"text-align: center; width: 100%;"})[1]
                    table2 = soup.find_all("table",attrs={"style":"text-align: center; width: 100%;"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[13]
                
                #second set
                if index == "secondset.txt":
                    table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[13]
                
                #third set
                if index == "thirdset.txt":
                    table = soup.find_all("table",attrs={"style":"text-align: center; width: 100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"text-align: center; width: 100%"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[10]
                
                #fourth set
                if index == "fourthset.txt":
                    table = soup.find_all("table",attrs={"style":"text-align: center; width: 100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"text-align: center; width: 100%"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[13]
                    
                #fifth set
                if index == "fifthset.txt":
                    table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[10]
                    
                #sixth set
                if index == "sixthset.txt":
                    table = soup.find_all("table",attrs={"style":"text-align:center; width:100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"text-align:center; width:100%"})[2]
                    ystrength = table.find_all("td")[1]
                    density = table2.find_all("td")[1]
                    emodulus = table2.find_all("td")[2]        
                    
                #seventh set
                if index == "seventhset.txt":
                    table = soup.find_all("table",attrs={"style":"text-align: center; width: 100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"text-align: center; width: 100%"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[7]
                    
                #eigth set
                if index == "eigthset.txt":
                    table = soup.find_all("table",attrs={"border":"0"})[1]
                    table2 = soup.find_all("table",attrs={"border":"0"})[2]
                    ystrength = table.find_all("p")[5]
                    density = table2.find_all("p")[3]
                    emodulus = table2.find_all("p")[7]
                    
                #ninth set
                if index == "ninthset.txt":
                    table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                    table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                    density = table.find_all("td")[1]
                    ystrength = table2.find_all("td")[4]
                    emodulus = table2.find_all("td")[10]
                
                if index == "misc.txt":
                        if line == "6620":
                            table = soup.find_all("table",attrs={"style":"text-align: center; width: 100%;"})[1]
                            table2 = soup.find_all("table",attrs={"style":"text-align: center; width: 100%;"})[2]
                            density = table.find_all("td")[1]
                            ystrength = table2.find_all("td")[4]
                            emodulus = table2.find_all("td")[10]
                        
                        if line == "6754":
                            table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                            table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                            density = table.find_all("td")[1]
                            ystrength = table2.find_all("td")[4]
                            emodulus = table2.find_all("td")[7]
                        
                        if line == "960":
                            table = soup.find_all("table",attrs={"width":"99%"})[0]
                            table2 = soup.find_all("table",attrs={"width":"99%"})[1]
                            ystrength = table.find_all("td")[9]
                            density = table2.find_all("p")[13]
                            emodulus = table2.find_all("p")[14]
                        
                        if line == "6575":
                            table = soup.find_all("table",attrs={"style":"text-align: center; width: 100%;"})[1]
                            table2 = soup.find_all("table",attrs={"style":"text-align: center; width: 100%;"})[2]
                            density = table.find_all("td")[1]
                            ystrength = table2.find_all("td")[4]
                            emodulus = table2.find_all("td")[7]
                        
                        if line == "6380":
                            table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                            table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                            density = table.find_all("td")[7]
                            ystrength = table2.find_all("td")[7]
                            emodulus = table2.find_all("td")[25]
                        
                        if line == "6371":
                            table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                            table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                            density = table.find_all("td")[1]
                            ystrength = table2.find_all("td")[4]
                            emodulus = table2.find_all("td")[19]
                        
                        if line == "6506":
                            table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                            table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                            density = table.find_all("td")[1]
                            ystrength = table2.find_all("td")[13]
                            emodulus = table2.find_all("td")[1]
                        
                        if line == "6396":
                            table = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[1]
                            table2 = soup.find_all("table",attrs={"style":"TEXT-ALIGN: center; WIDTH: 100%"})[2]
                            density = table.find_all("td")[1]
                            ystrength = table2.find_all("td")[13]
                            emodulus = table2.find_all("td")[5]
                            
                newdensity = density.text.strip().split()
                newdensity = newdensity[0].split("-")
                if float(newdensity[0]) > 10:
                    newdensity[0] = float(newdensity[0])/1000
                
                newyield = ystrength.text.strip().split()
                newyield = newyield[0].split("-")
                
                newelastic = emodulus.text.strip().split()
                newelastic = newelastic[0].split("-")
                
                densities.append(newdensity[0])
                yieldstrength.append(newyield[0])
                elasticmodulus.append(newelastic[0])

materialproperties = pd.DataFrame({"Materials": materials, "Density (g/cm3)": densities, "Yield Strength (MPa)": yieldstrength, "Elastic Modulus (GPa)": elasticmodulus})
materialproperties
# Out:
#                                             Materials Density (g/cm3)  \
# 0        Aluminium / Aluminum 6061 Alloy (UNS A96061)             2.7
# 1        Aluminum / Aluminium 3003 Alloy (UNS A93003)            2.73
# 2        Aluminium / Aluminum 6063 Alloy (UNS A96063)             2.7
# 3                 AISI 1065 Carbon Steel (UNS G10650)            7.85
# 4        Aluminium / Aluminum Alloy 3004 (UNS A93004)             2.6
# 5                  AISI 4140 Alloy Steel (UNS G41400)            7.85
# 6                    Aluminum 1199 Alloy (UNS A91199)            2.70
# 7                    Aluminum 2017 Alloy (UNS A92017)            2.79
# 8                    Aluminum 2090 Alloy (UNS A92090)            2.59
# 9                    Aluminum 2218 Alloy (UNS A92218)            2.82
# 10       Aluminium / Aluminum 2219 Alloy (UNS A92219)             2.6
# 11                 AISI 6150 Alloy Steel (UNS G61500)            7.85
# 12                 AISI 8620 Alloy Steel (UNS G86200)            7.85
# 13           Stainless Steel - Grade 304 (UNS S30400)             8.0
# 14           Stainless Steel - Grade 321 (UNS S32100)           8.027
# 15               AISI 1018 Carbon Steel  (UNS G10180)            7.87
# 16               AISI 1020 Carbon Steel  (UNS G10200)            7.87
# 17  Brass Alloys - Brass CZ114 Properties, Fabrica...            7.87
# 18  Brass Alloys - Brass CZ131 Properties, Fabrica...            7.87
# 19  Brass Alloys - Brass CZ108 Properties, Fabrica...            7.87
# 20  Brass Alloys - Brass CZ121 Properties, Fabrica...            7.87
# 21                     Medium Leaded Brass UNS C35000            8.47
# 22                    Brass – Copper Alloy UNS C46400            8.41
# 23       Aluminium / Aluminum 3105 Alloy (UNS A93015)             2.6
# 24                 AISI 8620 Alloy Steel (UNS G86200)            7.85
# 25           Stainless Steel - Grade 301 (UNS S30100)            7.88
# 26                AISI 1065 Carbon Steel (UNS G10650)            7.85
# 27                                   Brass UNS C28000            8.39
# 28                             Brass Alloy UNS C44300            8.53
# 29       Leaded High-Strength Yellow Brass UNS C86700            8.32
# 30                     Medium Leaded Brass UNS C34000            8.47
#
#    Yield Strength (MPa) Elastic Modulus (GPa)
# 0                   276                  68.9
# 1                   125                    70
# 2                    48                    70
# 3                   490                    80
# 4                   170                    70
# 5                   415                   190
# 6                   110                    62
# 7                    69                    72
# 8                   520                    76
# 9                   280                  74.4
# 10                   76                    70
# 11                  415                   190
# 12                  385                   140
# 13                  515                   193
# 14                  515                   193
# 15                  370                   205
# 16                  350                   205
# 17                  350                   205
# 18                  350                   205
# 19                  350                   205
# 20                  350                   205
# 21                 90.0                   117
# 22                  172                   117
# 23                  130                    70
# 24                  385                   190
# 25                  276                   193
# 26                  490                   200
# 27                  140                   117
# 28                  124                   117
# 29                  290                   117
# 30                  103                   117
